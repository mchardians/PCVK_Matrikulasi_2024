# %% [markdown]
# <a href="https://colab.research.google.com/github/mchardians/PCVK_Matrikulasi_2024/blob/main/Praktikum_1_Modul_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io, transform
from PIL import Image
from matplotlib import pylab as plt

# %%
urls = [
          "https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
          "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
          "https://scontent.fmlg16-1.fna.fbcdn.net/v/t39.30808-6/311664281_184471900759664_5273547538134638512_n.jpg?_nc_cat=110&ccb=1-7&_nc_sid=6ee11a&_nc_eui2=AeFRpibSGz_yzJEigszyOlPB82OE9VZmDc7zY4T1VmYNzpOnRSal__kIXtvfSVVZJVof6ccKiIELP3XI_dX57Sxl&_nc_ohc=yQ55p18DW2AQ7kNvgF7iJCb&_nc_ht=scontent.fmlg16-1.fna&_nc_gid=ASmETikOX5OfxDmQ1e39hTm&oh=00_AYAfI3e8naTTbFc-PZvT1JNL5EPrC5cWi8FTQKeuc3NOiQ&oe=670AF81D"
        ]

for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat([image, image_2])
  cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=474x237>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("Resolusi image : tinggi x lebar =", tinggi, " x ",lebar)
cv2_imshow(image_2)
# Out:
# Resolusi image : tinggi x lebar = 237  x  237
# <PIL.Image.Image image mode=RGB size=237x237>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range(lebar):
  image_3[int((tinggi)/2), y] = [255,255,255]
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=474x237>

# %% [markdown]
# **Pertanyaan**
#
# 1.   Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan
# menggunakan Google Colab?
# 2.   Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan? Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
# 1.   Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
#
#   `image = cv.resize(image, (0,0), fx=0.5, fy=0.5)`
#
#   Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
# 2.   Perhatikan potongan kode program berikut:
#
#   `for y in range(lebar):`
#
#   `image_3[int((tinggi)/2),y] = [255,255,255]`
#
#   Apakah kegunaan kode [255,255,255] ? Jelaskan!
# 1.   Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
#
# **Jawaban**
#
# 1.   Karena Google Colab mendukung python dalam menjalankan maupun menuliskan kode python di browser tanpa memerlukan banyak konfigurasi. Google Colab juga mendukung banyak pustaka (library) yang sering digunakan untuk pengembangan Artificial Intelegence (AI).
# 2.   Penjelasan kegunaan setiap library yang digunakan sebagai berikut:
#   *   **Numpy:** digunakan untuk memanipulasi array dan operasi matematika
#   *   **Pandas:** digunakan untuk memanipulasi dan menganalisis data
#   *   **CV2:** digunakan untuk pengolahan citra dan visi komputer
#   *   **Skimage:** digunakan untuk memanipulasi, analisis, dan transformasi gambar pada python
#   *   **Matplotlib:** digunakan untuk membuat visualisasi data dalam bentuk grafik atau plot
#
#   Hanya library **CV2, google.colab.patches, dan Skimage** yang digunakan pada praktikum ini.
# 1.   Kode tersebut digunakan untuk mengubah ukuran gambar dengan lebar dan tingginya dikurangi menjadi 50% dari ukuran aslinya, jika tidak dijalankan maka gambar akan tetap ditampilkan sesuai pada ukuran aslinya.
# 1.   Untuk memberikan warna putih pada garis horizontal putih di tengah image.
# 1.   Pixel dan resolusi saling berkaitan dalam menentukan kualitas gambar. Gambar dengan resolusi tinggi, yang terdiri dari lebih banyak pixel, cenderung memiliki kualitas visual yang lebih baik, detail yang lebih tajam, dan pengalaman visual yang lebih baik dibandingkan dengan gambar dengan resolusi rendah.

# %%
image_4 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_5 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range(lebar):
  image_4[y, int((tinggi)/2)] = [255,255,255]
final_frame = cv.hconcat((image_2, image_4))
cv2_imshow(final_frame)

for i in range(min(tinggi, lebar)):
    image_5[i, i] = [255, 255, 255]
for i in range(min(tinggi, lebar)):
    image_5[i, lebar - i - 1] = [255, 255, 255]
final_frame = cv.hconcat((image_2, image_5))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=474x237>
# <PIL.Image.Image image mode=RGB size=474x237>

# %%
src = io.imread("https://upload.wikimedia.org/wikipedia/commons/thumb/9/96/1_Kitten.jpg/405px-1_Kitten.jpg")
image_6_before = cv.cvtColor(src, cv.COLOR_BGR2RGB)
image_6 = cv.cvtColor(src, cv.COLOR_BGR2RGB)

y_tengah = int(tinggi / 2)
panjang_garis = int(lebar * 0.4)
x_awal = int((lebar - panjang_garis) / 2)
x_akhir = x_awal + panjang_garis

cv.line(image_6, (x_awal, y_tengah), (x_akhir, y_tengah), (255, 255, 255), 1)

final_frame = cv.hconcat((image_6_before, image_6))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=810x270>

# %%
image_7 = cv.cvtColor(src, cv.COLOR_BGR2RGB)

x_awal = 50
x_akhir = 150
y_tengah = 100
tinggi_kotak = 100

image_7[y_tengah - tinggi_kotak // 2:y_tengah + tinggi_kotak // 2, x_awal:x_akhir] = (255, 255, 255)

cv2_imshow(image_7)
# Out:
# <PIL.Image.Image image mode=RGB size=405x270>

# %%
ktp = cv.imread("Images/KTP.png")
ktp = cv.cvtColor(ktp, cv.COLOR_BGR2RGB)
plt.axis('off')
plt.imshow(ktp)
plt.show()

# %% [markdown]
# **2. Identifikasi kenapa menggunakan konversi warna BGR2RGB pada matplotlib dan tanpa konversi pada opencv?**
#
# **Jawab:**
# Konversi warna BGR2RGB pada matplotlib perlu dilakukan agar warna ditampilkan dengan benar, sedangkan pada OpenCV secara default menggunakan RGB sehingga tidak perlu dilakukan konversi warna.

# %%
resized_ktp = cv.resize(ktp, (500,300))
resized_ktp = cv.cvtColor(resized_ktp, cv.COLOR_BGR2RGB)

x_awal = 110
x_akhir = 340
y_tengah = 65
tinggi_kotak = 17

resized_ktp[y_tengah - tinggi_kotak // 2:y_tengah + tinggi_kotak // 2, x_awal:x_akhir] = (255, 0, 0)

x_awal = 123
x_akhir = 300
y_tengah = 87
tinggi_kotak = 15

resized_ktp[y_tengah - tinggi_kotak // 2:y_tengah + tinggi_kotak // 2, x_awal:x_akhir] = (255, 0, 255)

cv2_imshow(resized_ktp)
# Out:
# <PIL.Image.Image image mode=RGB size=500x300>
